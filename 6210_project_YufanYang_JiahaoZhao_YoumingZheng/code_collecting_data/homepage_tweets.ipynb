# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
CONSUMER_KEY = 'g98ma1alivKBO1F8mgxqsmhwW'
CONSUMER_SECRET = 'Wqqps3csXjVEZZIIZ49CwuWvjBEA0bGb2ym8ggdWNAi4ibq5rK'
ACCESS_TOKEN = '902363121804869634-vZ2NjxwulAqfGghqc7ml22JUBAGEFZf'
ACCESS_SECRET = 'UOvosciATenpQFDkOMq1LjRD8TJ1pcuwXPUyhtkku4xz5'

# %%
# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth)
    return api

# %%
# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name="NBA", count=200)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("20 recent tweets:\n")
for tweet in tweets[:20]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 200.
#
# 20 recent tweets:
#
# Behind-the-scenes at @HoustonRockets in prep of the #NBAPlayoffs!
#
# 🏀: #Rockets x #AllEyesNorth Game 2
# ⏰: 9:30pm/e… https://t.co/TmDWCFBdsB
#
# The @Timberwolves look to even the series 1-1, while the @HoustonRockets look to go up 2-0!
#
# #AllEyesNorth x… https://t.co/K3afuLGXS4
#
# The fans in OKC are some of the loudest in the NBA. The @OKCThunder feed off of their noise and energy, giving the… https://t.co/OpHFtfvk5q
#
# The @utahjazz look to even the series 1-1, while the @okcthunder look to go up 2-0!
#
# #TakeNote x #ThunderUp Game 2… https://t.co/hzKixjrI6B
#
# On the latest #NBABreakdown, @ShotMechanics of the #NBAPlaymakers takes a deep dive into @KingJames' ridiculous cha… https://t.co/OJK3pJj9sn
#
# The @cavs look to even the series 1-1, while the @Pacers look to go up 2-0!
#
# #WhateverItTakes x #Pacers Game 2: 7p… https://t.co/Bt9021BKTf
#
# ...

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(20))
# Out:
#                                                Tweets
# 0   Behind-the-scenes at @HoustonRockets in prep o...
# 1   The @Timberwolves look to even the series 1-1,...
# 2   The fans in OKC are some of the loudest in the...
# 3   The @utahjazz look to even the series 1-1, whi...
# 4   On the latest #NBABreakdown, @ShotMechanics of...
# 5   The @cavs look to even the series 1-1, while t...
# 6   RT @davidfholt: Hosting an international summi...
# 7   RT @cityofokc: You know @7A_mountain from her ...
# 8   To celebrate @KingJames passing Michael Jordan...
# 9   RT @WNBA: ONE MONTH from today, two of the mos...
# 10  RT @WNBA: ONE MONTH till the @DallasWings &amp...
# 11  When the 2018 @WNBA season tips off May 18th, ...
# 12  RT @jrnba: .@michaelb4jordan on what it means ...
# 13  RT @nbacares: Timeout Tip from @NBA Legend @Bi...
# 14  After leading the @PelicansNBA to a 2-0 series...
# 15  Delon Wright throws down the oop in transition...
# ...

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
print(tweets[0].user.followers_count)
# Out:
# 986718512105181185
# 2018-04-18 21:30:00
# Media Studio
# 69
# 9
# None
# None
# {'hashtags': [{'text': 'NBAPlayoffs', 'indices': [52, 64]}, {'text': 'Rockets', 'indices': [71, 79]}, {'text': 'AllEyesNorth', 'indices': [82, 95]}], 'symbols': [], 'user_mentions': [{'screen_name': 'HoustonRockets', 'name': 'Houston Rockets', 'id': 19077044, 'id_str': '19077044', 'indices': [21, 36]}], 'urls': [{'url': 'https://t.co/TmDWCFBdsB', 'expanded_url': 'https://twitter.com/i/web/status/986718512105181185', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}
# 27573536

# %%
# We add relevant data:
data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID']   = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])
data['text']   = np.array([tweet.text for tweet in tweets])
data['Followers']   = np.array([tweet.user.followers_count for tweet in tweets])

# %%
# Display of first 20 elements from dataframe:
display(data.head(20))
# Out:
#                                                Tweets  len  \
# 0   Behind-the-scenes at @HoustonRockets in prep o...  140
# 1   The @Timberwolves look to even the series 1-1,...  134
# 2   The fans in OKC are some of the loudest in the...  139
# 3   The @utahjazz look to even the series 1-1, whi...  140
# 4   On the latest #NBABreakdown, @ShotMechanics of...  140
# 5   The @cavs look to even the series 1-1, while t...  140
# 6   RT @davidfholt: Hosting an international summi...  138
# 7   RT @cityofokc: You know @7A_mountain from her ...  140
# 8   To celebrate @KingJames passing Michael Jordan...  140
# 9   RT @WNBA: ONE MONTH from today, two of the mos...  140
# 10  RT @WNBA: ONE MONTH till the @DallasWings &amp...  144
# 11  When the 2018 @WNBA season tips off May 18th, ...  140
# 12  RT @jrnba: .@michaelb4jordan on what it means ...  143
# 13  RT @nbacares: Timeout Tip from @NBA Legend @Bi...  140
# 14  After leading the @PelicansNBA to a 2-0 series...  140
# ...
